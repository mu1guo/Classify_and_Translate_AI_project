# %% [markdown]
# # 1、首先导入包

# %%
# 数据科学包
import random                      # 随机切分数据集
import numpy as np                 # 常用数据科学包
import os
from PIL import Image              # 图像读取
import matplotlib.pyplot as plt    # 代码中快速验证
import cv2                         # 图像包

# 深度学习包
import paddle
import paddle.vision.transforms as T       # 数据增强
from paddle.io import Dataset, DataLoader  # 定义数据集

# %% [markdown]
# # 2、解压数据集，对数据集进行增广，并创建dataset

# %%
# 解压数据集
if not os.path.exists('cat_12_train'):
    # !unzip data/data10954/cat_12_train.zip
    # !unzip data/data10954/cat_12_test.zip

# %%
# 按比例随机切割数据集
train_ratio = 0.9  # 训练集占0.9，验证集占0.1

train_paths, train_labels = [], []
valid_paths, valid_labels = [], []
with open('data/data10954/train_list.txt', 'r') as f:
    lines = f.readlines()
    for line in lines:
        if random.uniform(0, 1) < train_ratio:
            train_paths.append(line.split('	')[0])
            label = line.split('	')[1]
            train_labels.append(int(line.split('	')[1]))
        else:
            valid_paths.append(line.split('	')[0])
            valid_labels.append(int(line.split('	')[1]))

# %%
# 定义训练数据集
class TrainData(Dataset):
    def __init__(self):
        super().__init__()
        self.color_jitter = T.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05, hue=0.05)
        self.normalize = T.Normalize(mean=0, std=1)
        self.random_crop = T.RandomCrop(224, pad_if_needed=True)
    
    def __getitem__(self, index):
        # 读取图片
        image_path = train_paths[index]

        image = np.array(Image.open(image_path))    # H, W, C
        try:
            image = image.transpose([2, 0, 1])[:3]  # C, H, W
        except:
            image = np.array([image, image, image]) # C, H, W
        
        # 图像增广
        features = self.color_jitter(image.transpose([1, 2, 0]))
        features = self.random_crop(features)
        features = self.normalize(features.transpose([2, 0, 1])).astype(np.float32)

        # 读取标签
        labels = train_labels[index]

        return features, labels
    
    def __len__(self):
        return len(train_paths)

    
# 定义验证数据集
class ValidData(Dataset):
    def __init__(self):
        super().__init__()
        self.normalize = T.Normalize(mean=0, std=1)
    
    def __getitem__(self, index):
        # 读取图片
        image_path = valid_paths[index]

        image = np.array(Image.open(image_path))    # H, W, C
        try:
            image = image.transpose([2, 0, 1])[:3]  # C, H, W
        except:
            image = np.array([image, image, image]) # C, H, W
        
        # 图像变换
        features = cv2.resize(image.transpose([1, 2, 0]), (256, 256)).transpose([2, 0, 1]).astype(np.float32)
        features = self.normalize(features)

        # 读取标签
        labels = valid_labels[index]

        return features, labels
    
    def __len__(self):
        return len(valid_paths)

# %% [markdown]
# # 3、查看我们对猫猫进行的变换，从直觉上判断增广是否合理

# %%
train_data = TrainData()
img, labels = train_data.__getitem__(98)
plt.figure(dpi=40,figsize=(16,16))
plt.imshow(img.astype(np.uint8).transpose([1, 2, 0]))
plt.show()
# Out:
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data

# %%
valid_data = ValidData()
img, label = valid_data.__getitem__(134)
plt.figure(dpi=40,figsize=(16,16))
plt.imshow(img.astype(np.uint8).transpose([1, 2, 0]))

# %% [markdown]
# # 4、搭建网络模型，进行模型的训练与评估保存

# %%
# 调用resnet50模型
paddle.vision.set_image_backend('cv2')
model = paddle.vision.models.resnet50(pretrained=True, num_classes=12)

# 定义数据迭代器
train_dataloader = DataLoader(train_data, batch_size=256, shuffle=True, drop_last=False)

# 定义优化器
opt = paddle.optimizer.Adam(learning_rate=1e-4, parameters=model.parameters(), weight_decay=paddle.regularizer.L2Decay(1e-4))

# 定义损失函数
loss_fn = paddle.nn.CrossEntropyLoss()

# 设置gpu环境
paddle.set_device('gpu:0')

# 整体训练流程
for epoch_id in range(15):
    model.train()
    for batch_id, data in enumerate(train_dataloader()):
        # 读取数据
        features, labels = data
        features = paddle.to_tensor(features)
        labels = paddle.to_tensor(labels)

        # 前向传播
        predicts = model(features)

        # 损失计算
        loss = loss_fn(predicts, labels)

        # 反向传播
        avg_loss = paddle.mean(loss)
        avg_loss.backward()

        # 更新
        opt.step()

        # 清零梯度
        opt.clear_grad()

        # 打印损失
        if batch_id % 2 == 0:
            print('epoch_id:{}, batch_id:{}, loss:{}'.format(epoch_id, batch_id, avg_loss.numpy()))
    model.eval()
    print('开始评估')
    i = 0
    acc = 0
    for image, label in valid_data:
        image = paddle.to_tensor([image])

        pre = list(np.array(model(image)[0]))
        max_item = max(pre)
        pre = pre.index(max_item)

        i += 1
        if pre == label:
            acc += 1
        if i % 10 == 0:
            print('精度：', acc / i)
    
    paddle.save(model.state_dict(), 'acc{}.model'.format(acc / i))
# Out:
# W0112 22:53:39.803340   600 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 12.0, Runtime API Version: 11.2
# W0112 22:53:39.807425   600 gpu_resources.cc:91] device: 0, cuDNN Version: 8.2.
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1492: UserWarning: Skip loading for fc.weight. fc.weight receives a shape [2048, 1000], but the expected shape is [2048, 12].
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dygraph/layers.py:1492: UserWarning: Skip loading for fc.bias. fc.bias receives a shape [1000], but the expected shape is [12].
#   warnings.warn(("Skip loading for {}. ".format(key) + str(err)))
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/nn/layer/norm.py:654: UserWarning: When training, we now always track global mean and variance.
#   "When training, we now always track global mean and variance.")
# epoch_id:0, batch_id:0, loss:[2.6205313]
# epoch_id:0, batch_id:2, loss:[2.0257983]
# epoch_id:0, batch_id:4, loss:[1.5311643]
# epoch_id:0, batch_id:6, loss:[1.2435187]
# 开始评估
# 精度： 0.7
# 精度： 0.7
# 精度： 0.6
# 精度： 0.6
# 精度： 0.68
# 精度： 0.7166666666666667
# 精度： 0.7571428571428571
# 精度： 0.725
# 精度： 0.7
# 精度： 0.7
# 精度： 0.7090909090909091
# 精度： 0.7166666666666667
# 精度： 0.7153846153846154
# 精度： 0.7214285714285714
# 精度： 0.72
# 精度： 0.70625
# 精度： 0.7176470588235294
# 精度： 0.7166666666666667
# 精度： 0.7210526315789474
# 精度： 0.73
# 精度： 0.7238095238095238
# epoch_id:1, batch_id:0, loss:[0.90526485]
# epoch_id:1, batch_id:2, loss:[0.8001605]
# epoch_id:1, batch_id:4, loss:[0.6767552]
# epoch_id:1, batch_id:6, loss:[0.4986552]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9
# 精度： 0.9
# 精度： 0.88
# 精度： 0.8333333333333334
# 精度： 0.8571428571428571
# 精度： 0.875
# 精度： 0.8888888888888888
# 精度： 0.89
# 精度： 0.8727272727272727
# 精度： 0.8833333333333333
# 精度： 0.8923076923076924
# 精度： 0.8928571428571429
# 精度： 0.8866666666666667
# 精度： 0.89375
# 精度： 0.8941176470588236
# 精度： 0.8888888888888888
# 精度： 0.8842105263157894
# 精度： 0.89
# 精度： 0.8857142857142857
# epoch_id:2, batch_id:0, loss:[0.42805088]
# epoch_id:2, batch_id:2, loss:[0.36059934]
# epoch_id:2, batch_id:4, loss:[0.39034507]
# epoch_id:2, batch_id:6, loss:[0.36442724]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9
# 精度： 0.875
# 精度： 0.86
# 精度： 0.8333333333333334
# 精度： 0.8571428571428571
# 精度： 0.875
# 精度： 0.8888888888888888
# 精度： 0.85
# 精度： 0.8454545454545455
# 精度： 0.8583333333333333
# 精度： 0.8692307692307693
# 精度： 0.8785714285714286
# 精度： 0.8733333333333333
# 精度： 0.86875
# 精度： 0.8705882352941177
# 精度： 0.8722222222222222
# 精度： 0.8789473684210526
# 精度： 0.885
# 精度： 0.8857142857142857
# epoch_id:3, batch_id:0, loss:[0.30593753]
# epoch_id:3, batch_id:2, loss:[0.34546167]
# epoch_id:3, batch_id:4, loss:[0.22503088]
# epoch_id:3, batch_id:6, loss:[0.32752493]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8666666666666667
# 精度： 0.875
# 精度： 0.88
# 精度： 0.85
# 精度： 0.8714285714285714
# 精度： 0.8875
# 精度： 0.9
# 精度： 0.88
# 精度： 0.8727272727272727
# 精度： 0.875
# 精度： 0.8846153846153846
# 精度： 0.8928571428571429
# 精度： 0.8933333333333333
# 精度： 0.89375
# 精度： 0.8941176470588236
# 精度： 0.8888888888888888
# 精度： 0.8947368421052632
# 精度： 0.9
# 精度： 0.9047619047619048
# epoch_id:4, batch_id:0, loss:[0.2418505]
# epoch_id:4, batch_id:2, loss:[0.20524685]
# epoch_id:4, batch_id:4, loss:[0.24547276]
# epoch_id:4, batch_id:6, loss:[0.19606383]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9
# 精度： 0.925
# 精度： 0.94
# 精度： 0.9166666666666666
# 精度： 0.9285714285714286
# 精度： 0.9375
# 精度： 0.9444444444444444
# 精度： 0.92
# 精度： 0.9090909090909091
# 精度： 0.9083333333333333
# 精度： 0.9076923076923077
# 精度： 0.9142857142857143
# 精度： 0.9066666666666666
# 精度： 0.90625
# 精度： 0.9058823529411765
# 精度： 0.9
# 精度： 0.9
# 精度： 0.905
# 精度： 0.9095238095238095
# epoch_id:5, batch_id:0, loss:[0.13219626]
# epoch_id:5, batch_id:2, loss:[0.13330676]
# epoch_id:5, batch_id:4, loss:[0.19705623]
# epoch_id:5, batch_id:6, loss:[0.19049868]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9
# 精度： 0.8833333333333333
# 精度： 0.9
# 精度： 0.9125
# 精度： 0.9222222222222223
# 精度： 0.9
# 精度： 0.8909090909090909
# 精度： 0.8916666666666667
# 精度： 0.8923076923076924
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9
# 精度： 0.8888888888888888
# 精度： 0.8894736842105263
# 精度： 0.895
# 精度： 0.9
# epoch_id:6, batch_id:0, loss:[0.12420112]
# epoch_id:6, batch_id:2, loss:[0.09633646]
# epoch_id:6, batch_id:4, loss:[0.15946606]
# epoch_id:6, batch_id:6, loss:[0.12565833]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9333333333333333
# 精度： 0.875
# 精度： 0.82
# 精度： 0.7833333333333333
# 精度： 0.8142857142857143
# 精度： 0.825
# 精度： 0.8444444444444444
# 精度： 0.83
# 精度： 0.8272727272727273
# 精度： 0.8333333333333334
# 精度： 0.8384615384615385
# 精度： 0.85
# 精度： 0.8533333333333334
# 精度： 0.8625
# 精度： 0.8647058823529412
# 精度： 0.8555555555555555
# 精度： 0.8631578947368421
# 精度： 0.87
# 精度： 0.8761904761904762
# epoch_id:7, batch_id:0, loss:[0.08795215]
# epoch_id:7, batch_id:2, loss:[0.12601633]
# epoch_id:7, batch_id:4, loss:[0.1515922]
# epoch_id:7, batch_id:6, loss:[0.15398635]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.9333333333333333
# 精度： 0.925
# 精度： 0.94
# 精度： 0.9333333333333333
# 精度： 0.9428571428571428
# 精度： 0.95
# 精度： 0.9555555555555556
# 精度： 0.93
# 精度： 0.9363636363636364
# 精度： 0.9416666666666667
# 精度： 0.9384615384615385
# 精度： 0.9428571428571428
# 精度： 0.94
# 精度： 0.9375
# 精度： 0.9352941176470588
# 精度： 0.9277777777777778
# 精度： 0.9263157894736842
# 精度： 0.93
# 精度： 0.9333333333333333
# epoch_id:8, batch_id:0, loss:[0.09132563]
# epoch_id:8, batch_id:2, loss:[0.12318812]
# epoch_id:8, batch_id:4, loss:[0.10302479]
# epoch_id:8, batch_id:6, loss:[0.12498035]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8666666666666667
# 精度： 0.85
# 精度： 0.82
# 精度： 0.8
# 精度： 0.8285714285714286
# 精度： 0.85
# 精度： 0.8666666666666667
# 精度： 0.86
# 精度： 0.8727272727272727
# 精度： 0.8833333333333333
# 精度： 0.8846153846153846
# 精度： 0.8928571428571429
# 精度： 0.8933333333333333
# 精度： 0.89375
# 精度： 0.8941176470588236
# 精度： 0.8833333333333333
# 精度： 0.8789473684210526
# 精度： 0.885
# 精度： 0.8904761904761904
# epoch_id:9, batch_id:0, loss:[0.08756307]
# epoch_id:9, batch_id:2, loss:[0.09644474]
# epoch_id:9, batch_id:4, loss:[0.11350428]
# epoch_id:9, batch_id:6, loss:[0.11283828]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8333333333333334
# 精度： 0.85
# 精度： 0.88
# 精度： 0.8833333333333333
# 精度： 0.9
# 精度： 0.9125
# 精度： 0.9222222222222223
# 精度： 0.9
# 精度： 0.8909090909090909
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9071428571428571
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9
# 精度： 0.8888888888888888
# 精度： 0.8842105263157894
# 精度： 0.89
# 精度： 0.8952380952380953
# epoch_id:10, batch_id:0, loss:[0.08334753]
# epoch_id:10, batch_id:2, loss:[0.10866858]
# epoch_id:10, batch_id:4, loss:[0.12246342]
# epoch_id:10, batch_id:6, loss:[0.07642309]
# 开始评估
# 精度： 1.0
# 精度： 0.9
# 精度： 0.8333333333333334
# 精度： 0.85
# 精度： 0.88
# 精度： 0.8833333333333333
# 精度： 0.9
# 精度： 0.9125
# 精度： 0.9222222222222223
# 精度： 0.9
# 精度： 0.9
# 精度： 0.9083333333333333
# 精度： 0.9076923076923077
# 精度： 0.9142857142857143
# 精度： 0.9133333333333333
# 精度： 0.9125
# 精度： 0.9117647058823529
# 精度： 0.9
# 精度： 0.8947368421052632
# 精度： 0.9
# 精度： 0.9047619047619048
# epoch_id:11, batch_id:0, loss:[0.09057716]
# epoch_id:11, batch_id:2, loss:[0.06269999]
# epoch_id:11, batch_id:4, loss:[0.07378312]
# epoch_id:11, batch_id:6, loss:[0.06391697]
# 开始评估
# 精度： 1.0
# 精度： 0.9
# 精度： 0.8666666666666667
# 精度： 0.875
# 精度： 0.88
# 精度： 0.8666666666666667
# 精度： 0.8857142857142857
# 精度： 0.9
# 精度： 0.9111111111111111
# 精度： 0.89
# 精度： 0.8909090909090909
# 精度： 0.8916666666666667
# 精度： 0.9
# 精度： 0.9071428571428571
# 精度： 0.9
# 精度： 0.90625
# 精度： 0.9058823529411765
# 精度： 0.8944444444444445
# 精度： 0.8947368421052632
# 精度： 0.9
# 精度： 0.9047619047619048
# epoch_id:12, batch_id:0, loss:[0.05375751]
# epoch_id:12, batch_id:2, loss:[0.06169609]
# epoch_id:12, batch_id:4, loss:[0.04074167]
# epoch_id:12, batch_id:6, loss:[0.06234705]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8333333333333334
# 精度： 0.85
# 精度： 0.84
# 精度： 0.8333333333333334
# 精度： 0.8571428571428571
# 精度： 0.875
# 精度： 0.8888888888888888
# 精度： 0.88
# 精度： 0.8818181818181818
# 精度： 0.875
# 精度： 0.8769230769230769
# 精度： 0.8857142857142857
# 精度： 0.8866666666666667
# 精度： 0.8875
# 精度： 0.888235294117647
# 精度： 0.8833333333333333
# 精度： 0.8842105263157894
# 精度： 0.89
# 精度： 0.8952380952380953
# epoch_id:13, batch_id:0, loss:[0.068265]
# epoch_id:13, batch_id:2, loss:[0.03700925]
# epoch_id:13, batch_id:4, loss:[0.05752782]
# epoch_id:13, batch_id:6, loss:[0.07265302]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8
# 精度： 0.825
# 精度： 0.82
# 精度： 0.8166666666666667
# 精度： 0.8428571428571429
# 精度： 0.8625
# 精度： 0.8777777777777778
# 精度： 0.87
# 精度： 0.8818181818181818
# 精度： 0.8916666666666667
# 精度： 0.8923076923076924
# 精度： 0.9
# 精度： 0.9
# 精度： 0.90625
# 精度： 0.9058823529411765
# 精度： 0.9
# 精度： 0.9
# 精度： 0.905
# 精度： 0.9095238095238095
# epoch_id:14, batch_id:0, loss:[0.04169242]
# epoch_id:14, batch_id:2, loss:[0.05429331]
# epoch_id:14, batch_id:4, loss:[0.05092868]
# epoch_id:14, batch_id:6, loss:[0.0573142]
# 开始评估
# 精度： 1.0
# 精度： 0.95
# 精度： 0.8666666666666667
# 精度： 0.875
# 精度： 0.88
# 精度： 0.8833333333333333
# 精度： 0.9
# 精度： 0.9125
# 精度： 0.9222222222222223
# 精度： 0.92
# 精度： 0.9090909090909091
# 精度： 0.9166666666666666
# 精度： 0.9153846153846154
# 精度： 0.9214285714285714
# 精度： 0.92
# 精度： 0.91875
# 精度： 0.9117647058823529
# 精度： 0.9055555555555556
# 精度： 0.9105263157894737
# 精度： 0.915
# 精度： 0.919047619047619

# %% [markdown]
# # 5、加载模型进行预测，并提交结果

# %%
# 进行预测和提交
# 首先拿到预测文件的路径列表

def listdir(path, list_name):
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            listdir(file_path, list_name)
        else:
            list_name.append(file_path)
test_path = []
listdir('cat_12_test', test_path)

# 加载训练好的模型
pre_model = paddle.vision.models.resnet50(pretrained=True, num_classes=12)
pre_model.set_state_dict(paddle.load('acc0.9285714285714286.model'))
pre_model.eval()

pre_classes = []
normalize = T.Normalize(mean=0, std=1)
# 生成预测结果
for path in test_path:
    image_path = path

    image = np.array(Image.open(image_path))    # H, W, C
    try:
        image = image.transpose([2, 0, 1])[:3]  # C, H, W
    except:
        image = np.array([image, image, image]) # C, H, W
    
    # 图像变换
    features = cv2.resize(image.transpose([1, 2, 0]), (256, 256)).transpose([2, 0, 1]).astype(np.float32)
    features = normalize(features)

    features = paddle.to_tensor([features])
    pre = list(np.array(pre_model(features)[0]))
    # print(pre)
    max_item = max(pre)
    pre = pre.index(max_item)
    print("图片：", path, "预测结果：", pre)
    pre_classes.append(pre)

print(pre_classes)

# %%
# 导入csv模块
import csv

# 1、创建文件对象
with open('submit.csv', 'w', encoding='gbk', newline="") as f:
    # 2、基于文件对象构建csv写入对象
    csv_writer = csv.writer(f)
    for i in range(240):
        csv_writer.writerow([test_path[i].split('/')[1], pre_classes[i]])
    print('写入数据完成')
